# %%
import os
import sys
import cv2
import numpy as np
import matplotlib.pyplot as plt

current_path = os.getcwd()
print(current_path)
project_root_path = os.path.abspath(os.path.join(current_path, '..'))
print(project_root_path)

if project_root_path not in sys.path:
    sys.path.append(project_root_path)
    
from src.models.layers import Layers
# Out:
# /Users/ghoziwaridi/PEMOGRAMAN/Python/Deep_learning/CNN/Weed_detection/skenario
# /Users/ghoziwaridi/PEMOGRAMAN/Python/Deep_learning/CNN/Weed_detection

# %%
path = "/Users/ghoziwaridi/PEMOGRAMAN/Python/Deep_learning/CNN/Weed_detection/data/raw/ghozi.jpg"

img = cv2.imread(path)
print(img.shape)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img = cv2.resize(img, (64, 64))
plt.imshow(img, cmap="gray")
# Out:
# (4160, 2773, 3)

# %%
kernel = np.array([
    [0,  1, 0],
    [1, -4, 1],
    [0,  1, 0]
])

hasil = Layers.forward_layer(x=img, kernel=kernel, stride=2, pool_size=(2,2), pool_stride=2)
plt.plot(hasil)
print(hasil.shape)
print(hasil)
# Out:
# (225,)
# [  1.   2.   1.  17.   9.   2.   3.   0.   9.   2.   1.   4.   6.   2.
#    6.   2.   1.   0.  16.   0.   1.   0.   1.   8.   6.   5.   4.   6.
#    0.   6.   2.   1.   0.  22.   1.  16.   3.   3.   4.   3.   1.   1.
#    6.   5.   4.   3.   1.   3.   4.   1.   5.  65.  14.  85.  36.   3.
#    0.   1.   9.   1.   3.   0.   2.   1.   2. 114.  17.  57.  94. 327.
#    0.   0.   5.   6.   3.   2.   2.   4.  16.  15. 170.   1.  41. 123.
#  213.   0.   0.   0.   3.   1.   2.   5.   6.   6.   3.   6.   8.  12.
#   13.   7.  17.   6.   5.   6.   3.   2.   7.   2.  19.  72.  14.  94.
#   31.  59. 144.   7.   5.   7.   9.   7.   0.  11.   2.  89.  27.  37.
#    0. 123. 144.  91.  26.  21.  74.  15.   8.   1.   2.  61.  86.  65.
#   14.  49.  71.  12.  11. 118.  10. 204. 183.   5.   3.   6. 143. 175.
#   37. 130.   9.  71.  36.  87. 227.  20. 145. 218.   2.   0.   3.  59.
#   47.  20.  19.  17.   0.  55.   0.  18.  92. 145.  15.  10.   3.   2.
# ...
